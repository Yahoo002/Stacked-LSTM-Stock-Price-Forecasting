# %%
import pandas as pd
df = pd.read_csv('MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060274
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062427
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063504
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061889
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060812
# ...          ...         ...         ...         ...         ...         ...
# 9494  2023-11-13  368.220001  368.470001  365.899994  366.679993  365.937256
# 9495  2023-11-14  371.010010  371.950012  367.350006  370.269989  369.519989
# 9496  2023-11-15  371.279999  373.130005  367.109985  369.670013  369.670013
# 9497  2023-11-16  370.959991  376.350006  370.179993  376.170013  376.170013
# 9498  2023-11-17  373.609985  374.369995  367.000000  369.850006  369.850006
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9494    19986500
# 9495    27683900
# 9496    26860100
# 9497    27182300
# 9498    40157000
#
# [9499 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9494  2023-11-13  366.679993
# 9495  2023-11-14  370.269989
# 9496  2023-11-15  369.670013
# 9497  2023-11-16  376.170013
# 9498  2023-11-17  369.850006
#
# [9499 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9494    2023-11-13
# 9495    2023-11-14
# 9496    2023-11-15
# 9497    2023-11-16
# 9498    2023-11-17
# Name: Date, Length: 9499, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9494  2023-11-13  366.679993
# 9495  2023-11-14  370.269989
# 9496  2023-11-15  369.670013
# 9497  2023-11-16  376.170013
# 9498  2023-11-17  369.850006
#
# [9499 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-6-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9494   2023-11-13
# 9495   2023-11-14
# 9496   2023-11-15
# 9497   2023-11-16
# 9498   2023-11-17
# Name: Date, Length: 9499, dtype: datetime64[ns]

# %%
df
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9494 2023-11-13  366.679993
# 9495 2023-11-14  370.269989
# 9496 2023-11-15  369.670013
# 9497 2023-11-16  376.170013
# 9498 2023-11-17  369.850006
#
# [9499 rows x 2 columns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-11-13  366.679993
# 2023-11-14  370.269989
# 2023-11-15  369.670013
# 2023-11-16  376.170013
# 2023-11-17  369.850006
#
# [9499 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 161ms/step - loss: 84322.9844 - mean_absolute_error: 288.6405 - val_loss: 91896.6484 - val_mean_absolute_error: 303.0573
# Epoch 2/100
# 7/7 [==============================] - 0s 15ms/step - loss: 83933.5547 - mean_absolute_error: 287.9638 - val_loss: 91491.5781 - val_mean_absolute_error: 302.3882
# Epoch 3/100
# 7/7 [==============================] - 0s 15ms/step - loss: 83533.2422 - mean_absolute_error: 287.2704 - val_loss: 91033.4375 - val_mean_absolute_error: 301.6297
# Epoch 4/100
# 7/7 [==============================] - 0s 72ms/step - loss: 83059.5312 - mean_absolute_error: 286.4432 - val_loss: 90440.0625 - val_mean_absolute_error: 300.6444
# Epoch 5/100
# 7/7 [==============================] - 0s 59ms/step - loss: 82411.7891 - mean_absolute_error: 285.3097 - val_loss: 89663.3203 - val_mean_absolute_error: 299.3499
# Epoch 6/100
# 7/7 [==============================] - 0s 21ms/step - loss: 81666.2578 - mean_absolute_error: 283.9966 - val_loss: 88826.5312 - val_mean_absolute_error: 297.9489
# Epoch 7/100
# 7/7 [==============================] - 0s 18ms/step - loss: 80810.4453 - mean_absolute_error: 282.4948 - val_loss: 87829.4297 - val_mean_absolute_error: 296.2709
# Epoch 8/100
# 7/7 [==============================] - 0s 17ms/step - loss: 79780.4141 - mean_absolute_error: 280.6600 - val_loss: 86537.6484 - val_mean_absolute_error: 294.0826
# Epoch 9/100
# 7/7 [==============================] - 0s 18ms/step - loss: 78269.7969 - mean_absolute_error: 277.9506 - val_loss: 84413.6172 - val_mean_absolute_error: 290.4489
# Epoch 10/100
# 7/7 [==============================] - 0s 16ms/step - loss: 75989.0391 - mean_absolute_error: 273.8127 - val_loss: 81549.0625 - val_mean_absolute_error: 285.4751
# Epoch 11/100
# 7/7 [==============================] - 0s 14ms/step - loss: 73119.5547 - mean_absolute_error: 268.5249 - val_loss: 78281.5312 - val_mean_absolute_error: 279.6934
# Epoch 12/100
# 7/7 [==============================] - 0s 16ms/step - loss: 69748.5859 - mean_absolute_error: 262.1537 - val_loss: 74350.9844 - val_mean_absolute_error: 272.5764
# Epoch 13/100
# 7/7 [==============================] - 0s 17ms/step - loss: 65883.8359 - mean_absolute_error: 254.7039 - val_loss: 69968.3672 - val_mean_absolute_error: 264.4149
# Epoch 14/100
# 7/7 [==============================] - 0s 16ms/step - loss: 61521.6133 - mean_absolute_error: 245.9627 - val_loss: 65076.5508 - val_mean_absolute_error: 254.9968
# Epoch 15/100
# 7/7 [==============================] - 0s 14ms/step - loss: 56664.6133 - mean_absolute_error: 235.8751 - val_loss: 59438.2617 - val_mean_absolute_error: 243.6909
# Epoch 16/100
# 7/7 [==============================] - 0s 11ms/step - loss: 51448.2500 - mean_absolute_error: 224.5425 - val_loss: 53888.2109 - val_mean_absolute_error: 232.0238
# Epoch 17/100
# 7/7 [==============================] - 0s 12ms/step - loss: 45882.9883 - mean_absolute_error: 211.8166 - val_loss: 47422.9336 - val_mean_absolute_error: 217.6462
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 39920.1328 - mean_absolute_error: 197.2740 - val_loss: 41272.2812 - val_mean_absolute_error: 203.0254
# Epoch 19/100
# 7/7 [==============================] - 0s 11ms/step - loss: 34301.3477 - mean_absolute_error: 182.3853 - val_loss: 35216.8867 - val_mean_absolute_error: 187.5204
# Epoch 20/100
# 7/7 [==============================] - 0s 10ms/step - loss: 28751.5703 - mean_absolute_error: 166.5456 - val_loss: 29338.5684 - val_mean_absolute_error: 171.1304
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 23464.9629 - mean_absolute_error: 149.8235 - val_loss: 23745.6992 - val_mean_absolute_error: 153.9244
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 18543.9629 - mean_absolute_error: 132.3757 - val_loss: 18570.0195 - val_mean_absolute_error: 136.0770
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 13991.1172 - mean_absolute_error: 113.7199 - val_loss: 13574.6826 - val_mean_absolute_error: 116.2830
# Epoch 24/100
# 7/7 [==============================] - 0s 12ms/step - loss: 9942.7676 - mean_absolute_error: 94.5221 - val_loss: 9698.6172 - val_mean_absolute_error: 98.2123
# Epoch 25/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6935.0518 - mean_absolute_error: 76.7427 - val_loss: 6618.9751 - val_mean_absolute_error: 81.0309
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4649.9111 - mean_absolute_error: 60.0901 - val_loss: 4319.3760 - val_mean_absolute_error: 65.3178
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3061.0283 - mean_absolute_error: 45.7520 - val_loss: 2689.2053 - val_mean_absolute_error: 51.3443
# Epoch 28/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2033.6777 - mean_absolute_error: 36.2815 - val_loss: 1645.6891 - val_mean_absolute_error: 39.9090
# Epoch 29/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1487.0555 - mean_absolute_error: 32.0587 - val_loss: 992.9916 - val_mean_absolute_error: 30.6599
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1176.2937 - mean_absolute_error: 28.9646 - val_loss: 617.1235 - val_mean_absolute_error: 23.7520
# Epoch 31/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1066.0204 - mean_absolute_error: 27.7311 - val_loss: 415.7151 - val_mean_absolute_error: 19.0460
# Epoch 32/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1020.3361 - mean_absolute_error: 27.0100 - val_loss: 314.5887 - val_mean_absolute_error: 16.1748
# Epoch 33/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.9688 - mean_absolute_error: 26.8675 - val_loss: 261.5943 - val_mean_absolute_error: 14.5463
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.1713 - mean_absolute_error: 26.8493 - val_loss: 243.1236 - val_mean_absolute_error: 13.9445
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1011.0360 - mean_absolute_error: 26.8877 - val_loss: 238.1789 - val_mean_absolute_error: 13.7784
# Epoch 36/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1011.7476 - mean_absolute_error: 26.8940 - val_loss: 245.9704 - val_mean_absolute_error: 14.0391
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.2194 - mean_absolute_error: 26.8915 - val_loss: 244.4723 - val_mean_absolute_error: 13.9894
# Epoch 38/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.8599 - mean_absolute_error: 26.8786 - val_loss: 257.6697 - val_mean_absolute_error: 14.4208
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.5424 - mean_absolute_error: 26.8626 - val_loss: 269.4874 - val_mean_absolute_error: 14.7954
# Epoch 40/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.9067 - mean_absolute_error: 26.8567 - val_loss: 270.2827 - val_mean_absolute_error: 14.8202
# Epoch 41/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1010.0226 - mean_absolute_error: 26.8573 - val_loss: 272.7251 - val_mean_absolute_error: 14.8962
# Epoch 42/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.5355 - mean_absolute_error: 26.8482 - val_loss: 260.8837 - val_mean_absolute_error: 14.5237
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1011.5478 - mean_absolute_error: 26.8823 - val_loss: 266.3874 - val_mean_absolute_error: 14.6981
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1010.8909 - mean_absolute_error: 26.8760 - val_loss: 257.6863 - val_mean_absolute_error: 14.4213
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.9138 - mean_absolute_error: 26.8620 - val_loss: 265.7373 - val_mean_absolute_error: 14.6777
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.7585 - mean_absolute_error: 26.8525 - val_loss: 271.5260 - val_mean_absolute_error: 14.8590
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1009.7023 - mean_absolute_error: 26.8537 - val_loss: 271.5318 - val_mean_absolute_error: 14.8592
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.8352 - mean_absolute_error: 26.8568 - val_loss: 272.8461 - val_mean_absolute_error: 14.9000
# Epoch 49/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1009.8051 - mean_absolute_error: 26.8560 - val_loss: 274.3863 - val_mean_absolute_error: 14.9477
# Epoch 50/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1009.6566 - mean_absolute_error: 26.8546 - val_loss: 275.7590 - val_mean_absolute_error: 14.9901
# Epoch 51/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1009.3029 - mean_absolute_error: 26.8482 - val_loss: 280.5782 - val_mean_absolute_error: 15.1404
# Epoch 52/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1002.7477 - mean_absolute_error: 26.7577 - val_loss: 332.0409 - val_mean_absolute_error: 16.7088
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1003.7881 - mean_absolute_error: 26.8212 - val_loss: 261.1531 - val_mean_absolute_error: 14.5379
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 989.3997 - mean_absolute_error: 26.5445 - val_loss: 419.6913 - val_mean_absolute_error: 19.1896
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 974.6196 - mean_absolute_error: 26.3722 - val_loss: 309.0589 - val_mean_absolute_error: 16.0495
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 966.7687 - mean_absolute_error: 26.3153 - val_loss: 304.6987 - val_mean_absolute_error: 15.9285
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 942.2734 - mean_absolute_error: 25.9477 - val_loss: 324.0657 - val_mean_absolute_error: 16.5620
# Epoch 58/100
# 7/7 [==============================] - 0s 10ms/step - loss: 913.2375 - mean_absolute_error: 25.4919 - val_loss: 306.8029 - val_mean_absolute_error: 16.0485
# Epoch 59/100
# 7/7 [==============================] - 0s 10ms/step - loss: 885.8387 - mean_absolute_error: 25.1611 - val_loss: 351.9539 - val_mean_absolute_error: 17.4297
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 860.4938 - mean_absolute_error: 24.8788 - val_loss: 285.0894 - val_mean_absolute_error: 15.4021
# Epoch 61/100
# 7/7 [==============================] - 0s 10ms/step - loss: 831.8514 - mean_absolute_error: 24.3750 - val_loss: 262.4929 - val_mean_absolute_error: 14.6996
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 799.1424 - mean_absolute_error: 23.8279 - val_loss: 252.9331 - val_mean_absolute_error: 14.4200
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 747.9475 - mean_absolute_error: 23.0767 - val_loss: 236.9413 - val_mean_absolute_error: 13.9231
# Epoch 64/100
# 7/7 [==============================] - 0s 11ms/step - loss: 704.1472 - mean_absolute_error: 22.3775 - val_loss: 225.8019 - val_mean_absolute_error: 13.5686
# Epoch 65/100
# 7/7 [==============================] - 0s 10ms/step - loss: 653.6727 - mean_absolute_error: 21.4849 - val_loss: 173.5025 - val_mean_absolute_error: 11.6609
# Epoch 66/100
# 7/7 [==============================] - 0s 11ms/step - loss: 607.2725 - mean_absolute_error: 20.7126 - val_loss: 274.5275 - val_mean_absolute_error: 15.3223
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 566.5827 - mean_absolute_error: 19.9871 - val_loss: 173.5992 - val_mean_absolute_error: 11.7368
# Epoch 68/100
# 7/7 [==============================] - 0s 10ms/step - loss: 506.3687 - mean_absolute_error: 18.8749 - val_loss: 289.6241 - val_mean_absolute_error: 15.9013
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 474.3603 - mean_absolute_error: 17.7332 - val_loss: 289.4491 - val_mean_absolute_error: 15.9220
# Epoch 70/100
# 7/7 [==============================] - 0s 12ms/step - loss: 425.7960 - mean_absolute_error: 17.0789 - val_loss: 185.6352 - val_mean_absolute_error: 12.2881
# Epoch 71/100
# 7/7 [==============================] - 0s 10ms/step - loss: 363.0750 - mean_absolute_error: 15.5607 - val_loss: 86.4650 - val_mean_absolute_error: 7.7165
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 345.5209 - mean_absolute_error: 14.9795 - val_loss: 51.3943 - val_mean_absolute_error: 5.7009
# Epoch 73/100
# 7/7 [==============================] - 0s 10ms/step - loss: 308.5723 - mean_absolute_error: 14.6924 - val_loss: 96.7419 - val_mean_absolute_error: 8.3668
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 255.8386 - mean_absolute_error: 13.1779 - val_loss: 132.7870 - val_mean_absolute_error: 10.1430
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 244.3286 - mean_absolute_error: 12.6414 - val_loss: 74.6271 - val_mean_absolute_error: 7.1393
# Epoch 76/100
# 7/7 [==============================] - 0s 10ms/step - loss: 194.8800 - mean_absolute_error: 11.3452 - val_loss: 113.8781 - val_mean_absolute_error: 9.2294
# Epoch 77/100
# 7/7 [==============================] - 0s 12ms/step - loss: 155.5497 - mean_absolute_error: 9.8483 - val_loss: 61.2181 - val_mean_absolute_error: 6.4643
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 131.1331 - mean_absolute_error: 8.9577 - val_loss: 48.3068 - val_mean_absolute_error: 5.7501
# Epoch 79/100
# 7/7 [==============================] - 0s 10ms/step - loss: 110.6353 - mean_absolute_error: 7.8196 - val_loss: 73.5700 - val_mean_absolute_error: 7.1816
# Epoch 80/100
# 7/7 [==============================] - 0s 10ms/step - loss: 111.9000 - mean_absolute_error: 8.3085 - val_loss: 75.0763 - val_mean_absolute_error: 7.2826
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 98.6364 - mean_absolute_error: 7.9589 - val_loss: 35.9736 - val_mean_absolute_error: 5.1789
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74.7139 - mean_absolute_error: 6.2902 - val_loss: 30.1688 - val_mean_absolute_error: 4.8698
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 66.1995 - mean_absolute_error: 5.8878 - val_loss: 30.3804 - val_mean_absolute_error: 4.8742
# Epoch 84/100
# 7/7 [==============================] - 0s 11ms/step - loss: 57.7268 - mean_absolute_error: 5.5671 - val_loss: 41.9706 - val_mean_absolute_error: 5.1313
# Epoch 85/100
# 7/7 [==============================] - 0s 9ms/step - loss: 58.9988 - mean_absolute_error: 5.7833 - val_loss: 33.3518 - val_mean_absolute_error: 4.8658
# Epoch 86/100
# 7/7 [==============================] - 0s 9ms/step - loss: 51.0460 - mean_absolute_error: 5.3735 - val_loss: 35.3094 - val_mean_absolute_error: 4.8860
# Epoch 87/100
# 7/7 [==============================] - 0s 10ms/step - loss: 43.5135 - mean_absolute_error: 4.8655 - val_loss: 32.5204 - val_mean_absolute_error: 4.8569
# Epoch 88/100
# 7/7 [==============================] - 0s 10ms/step - loss: 40.5660 - mean_absolute_error: 4.8562 - val_loss: 30.5871 - val_mean_absolute_error: 4.8118
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 39.2321 - mean_absolute_error: 4.8184 - val_loss: 30.6193 - val_mean_absolute_error: 4.8073
# Epoch 90/100
# 7/7 [==============================] - 0s 12ms/step - loss: 39.9419 - mean_absolute_error: 4.8677 - val_loss: 32.9628 - val_mean_absolute_error: 4.8588
# Epoch 91/100
# 7/7 [==============================] - 0s 10ms/step - loss: 35.0060 - mean_absolute_error: 4.5899 - val_loss: 31.3523 - val_mean_absolute_error: 4.8271
# Epoch 92/100
# 7/7 [==============================] - 0s 10ms/step - loss: 33.4542 - mean_absolute_error: 4.5240 - val_loss: 52.0154 - val_mean_absolute_error: 5.6195
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 31.5314 - mean_absolute_error: 4.3971 - val_loss: 32.0944 - val_mean_absolute_error: 4.8389
# Epoch 94/100
# 7/7 [==============================] - 0s 10ms/step - loss: 32.2389 - mean_absolute_error: 4.4557 - val_loss: 38.9877 - val_mean_absolute_error: 4.9802
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 30.8556 - mean_absolute_error: 4.3386 - val_loss: 51.0203 - val_mean_absolute_error: 5.6048
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 29.5823 - mean_absolute_error: 4.2741 - val_loss: 52.0331 - val_mean_absolute_error: 5.6651
# Epoch 97/100
# 7/7 [==============================] - 0s 11ms/step - loss: 29.0666 - mean_absolute_error: 4.2963 - val_loss: 51.1807 - val_mean_absolute_error: 5.6318
# Epoch 98/100
# 7/7 [==============================] - 0s 10ms/step - loss: 29.0313 - mean_absolute_error: 4.3060 - val_loss: 52.4333 - val_mean_absolute_error: 5.6940
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 28.8592 - mean_absolute_error: 4.3261 - val_loss: 49.5369 - val_mean_absolute_error: 5.5634
# Epoch 100/100
# 7/7 [==============================] - 0s 9ms/step - loss: 26.3395 - mean_absolute_error: 4.0005 - val_loss: 69.0566 - val_mean_absolute_error: 6.5652

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 4ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
